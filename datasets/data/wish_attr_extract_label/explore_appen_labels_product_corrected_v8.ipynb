# %%
import pandas as pd
from collections import defaultdict
import dvc.api
from tqdm import tqdm
import numpy as np
from functools import reduce

# %% [markdown]
# # get original data

# %%
df_original = pd.concat([ 
    pd.read_csv(dvc.api.get_url('datasets/data/wish_attr_extract_label/appen/input_batch_processed/appen_product_attribution_batch1.csv', 
        repo='git@github.com:ContextLogic/multitask-llm-rnd.git')), 
    pd.read_csv(dvc.api.get_url('datasets/data/wish_attr_extract_label/appen/input_batch_processed/appen_product_attribution_batch2_highimpression.csv',
        repo='git@github.com:ContextLogic/multitask-llm-rnd.git')), 
    pd.read_csv(dvc.api.get_url('datasets/data/wish_attr_extract_label/appen/input_batch_processed/appen_product_attribution_batch2.csv', 
        repo='git@github.com:ContextLogic/multitask-llm-rnd.git')),
    pd.read_csv(dvc.api.get_url('datasets/data/wish_attr_extract_label/appen/input_batch_processed/appen_product_attribution_batch3.csv', 
        repo='git@github.com:ContextLogic/multitask-llm-rnd.git')),
    pd.read_csv(dvc.api.get_url('datasets/data/wish_attr_extract_label/appen/input_batch_processed/appen_product_attribution_batch4.csv', 
        repo='git@github.com:ContextLogic/multitask-llm-rnd.git'))
])

# %%
len(df_original)
# Out:
# 241287

# %%
df_original = df_original.dropna(subset=['label_ordering'])

# %%
len(df_original)
# Out:
# 241282

# %%
df_original['label_ordering'] = df_original['label_ordering'].astype(int)

# %% [markdown]
# # get attributes

# %%
df_attributes = pd.read_csv('../attribute_extraction_metadata_template/attribute_definition_top25L2_filtered_augmented_redacted_addedsinglemulti_01182023.csv')

df_attributes_group = df_attributes.groupby('attribute_field').agg({
    'category_attributevalue': lambda x: reduce(lambda x, y: x+y, [eval(i) for i in x])
}).reset_index()

# %%
len(df_attributes_group), df_attributes_group.category_attributevalue.apply(len).sum()
# Out:
# (230, 516378)

# %%
attributes = set(df_attributes_group['attribute_field'])

# %%
category_paths = set(df_attributes['category'])

# %%
more_paths = []
for i in category_paths:
    tmp = []
    for j in i.split(' > '):
        tmp.append(j)
        more_paths.append(' > '.join(tmp))
category_paths.update(more_paths)

# %% [markdown]
# # existing appen data

# %%
dflast = pd.read_csv('appen/output_batch_correct_v9/product_attribution_3.5k_04_06.csv_rework.csv')
df0 = pd.read_csv('appen/output_batch_correct_v8/Product Att_03.31.23_2746units.csv')
df1 = pd.read_csv('appen/output_batch_correct_v5/product_attribution_till_032423_valid_units.csv')
df2 = pd.read_csv('appen/output_batch_correct_v6/product_attribution_just_032723_valid_units.csv')
df3 = pd.read_csv('appen/output_batch_correct_v8/Product Att_03.2723_empty_missed_rework_6773_valid.csv')
df4 = pd.read_csv('appen/output_batch_correct_v8/Product Att_03.31.23_72units.csv')
df5 = pd.concat([
    pd.read_csv('appen/output_batch_correct_v8/Product Att_03.30.23_Batch3A_valid.csv'),
    pd.read_csv('appen/output_batch_correct_v8/Product Att_03.30.23_Batch3B_valid.csv'),
    pd.read_csv('appen/output_batch_correct_v8/Product Att_03.31.23_Batch4A.csv'),
    pd.read_csv('appen/output_batch_correct_v8/Product Att_03.31.23_Batch4B.csv'),
])
df6 = pd.read_csv('appen/output_batch_correct_v7/product_attribution_missed_032423_just_032723_invalid_units_fixed.csv')
df7 = pd.read_csv('appen/output_batch_correct_v6/product_attribution_just_032723_invalid_units_fixed.csv')
df8 = pd.read_csv('appen/output_batch_correct_v5/product_attribution_till_032423_invalid_units_fixed.csv')

# %%
dflast['file_name'] = "product_attribution_3.5k_04_06.csv_rework.csv"
df0['file_name'] = 'Product Att_03.31.23_2746units.csv'
df1['file_name'] = 'product_attribution_till_032423_valid_units.csv'
df2['file_name'] = 'product_attribution_just_032723_valid_units.csv'
df3['file_name'] = 'Product Att_03.2723_empty_missed_rework_6773_valid.csv'
df4['file_name'] = 'Product Att_03.31.23_72units.csv'
df5['file_name'] = 'Product Att_03.30.23_Batch3A_valid.csv|Product Att_03.30.23_Batch3B_valid.csv|Product Att_03.31.23_Batch4A.csv|Product Att_03.31.23_Batch4B.csv'
df6['file_name'] = 'product_attribution_missed_032423_just_032723_invalid_units_fixed.csv'
df7['file_name'] = 'product_attribution_just_032723_invalid_units_fixed.csv'
df8['file_name'] = 'product_attribution_till_032423_invalid_units_fixed.csv'

# %%
len(dflast), len(df0), len(df1), len(df2), len(df3), len(df4), len(df5), len(df6), len(df7), len(df8)
# Out:
# (3517, 2746, 48254, 43525, 6773, 72, 127349, 7789, 912, 3289)

# %%
dflast = dflast.rename(columns={'rater_output': 'rater3_output'})

# %%
df = pd.concat([dflast, df0, df1, df2, df3, df4, df5, df6, df7, df8])

# %%
len(df), len(set(df['label_ordering'])), len(set(df['label_ordering']))
# Out:
# (244226, 240673, 240673)

# %%
set(df['label_ordering']) - set(df_original['label_ordering'])
# Out:
# set()

# %%
len(set(df_original['label_ordering']) - set(df['label_ordering']))
# Out:
# 609

# %%
df_uniq = df.drop_duplicates('label_ordering', keep='first')

# %%
len(df), len(df_uniq)
# Out:
# (244226, 240673)

# %%
set(df_uniq)
# Out:
# {'category_path',
#  'explanation',
#  'file_name',
#  'final_output',
#  'final_output_corrected',
#  'l2_category',
#  'label_ordering',
#  'main_image_url',
#  'no_attributes',
#  'product_category',
#  'product_description',
#  'product_description_original',
#  'product_id',
#  'rater1_no_attributes',
#  'rater1_output',
#  'rater1_unlisted_value',
#  'rater2_no_attributes',
#  'rater2_output',
#  'rater2_unlisted_value',
#  'rater3_no_attributes',
#  'rater3_output',
#  'rater3_unlisted_value',
#  'sample_method',
#  'title',
#  'title_original',
#  'unlisted_value'}

# %%
df_uniq_merge = df_uniq.merge(df_original[['label_ordering', 'title', 'product_description', 'main_image_url',
                                           ]].rename(
    columns={'title': 'title_original2', 'product_description': 'product_description_original2',
             'main_image_url': 'main_image_url_original2',}), on='label_ordering', how='left')

# %%
len(df_uniq_merge)
# Out:
# 240673

# %%
df_uniq_merge[df_uniq_merge.title.apply(lambda x: str(x).strip()) != df_uniq_merge.title_original2.apply(lambda x: str(x).strip())]
# Out:
#         label_ordering sample_method                product_id  \
# 47874           162392  text_and_img  5cdd05b52e33a70fe773d613
# 114291          118572     only_text  60653b38ddc105a55285a859
# 114663          119230  text_and_img  610105dfe1fcdddd74dffd8d
# 115076          119970  text_and_img  60ea51ce0d9cc11e19e1be19
# 117029          123837     only_text  60fe204548a7aecbeb1c2231
# 121006          130728     only_text  60e94199fa08d2604699c7a3
# 123805          135885     only_text  60fbe4f2bcc4b88c38565afd
# 126913          141286  text_and_img  607042d6a68cb218c3bcae06
# 127905          143016  text_and_img  611a75c952e8fa7c477130bf
# 129552          145650     only_text  6118adac154b7afd9fc2709a
# 131911          149334     only_text  60bb2ea6cba4c340e437b1d9
# 135760          105302     only_text  60ea51c7f5cdd952b5f963cd
# 177597          200798  text_and_img  6155e2bf9fc94560c75db541
# 200775          224084  text_and_img  619cbbfb7eead9fb3c223527
# 203131          226445  text_and_img  60cc8c80b5970a361bbf75f8
#
#                                                     title  \
# 47874   Lixada Breathable  Fishing Life Vest  209lb Bu...
# 114291  American Europe Women's Fashion Jewelry Antiqu...
# 114663  Apple AirPods with Wireless Charging Case MRXJ...
# 115076  Blue Wolf Dream Catcher Chest Pack Unisex Slin...
# 117029  7x Leather Craft Half-Round Strap Belt End Pun...
# 121006  Hexagram Chest Pack Unisex Sling Backpack Casu...
# 123805  Fear Nothing' Hip Hop Men's Fashion 925 Sterli...
# 126913      Freedom or Death' Mens Punk Gothic Skull Ring
# 127905  Roses Are Red Doritos Are Savory The Us zfd Ph...
# 129552  Thin Red Line Union Jack Uk Flag ysf Phone Cas...
# 131911  JUST SO SO' Breathable UNISEX Running Shoes | ...
# 135760  Cock Chest Pack Unisex Sling Backpack Casual T...
# 177597                                             #NAME?
# 200775                                             #NAME?
# 203131                                             #NAME?
#
#                                       product_description  \
# 47874   This fishing Life jacket looks more like an ou...
# 114291  Stone: Moonstone\nColor: silver\nSize (US): 5 ...
# 114663  Feature:\nLatest and best AirPod\n\nLighting c...
# 115076  1.HIGH QUALITY: This Stylish Sling Bag Is Made...
# 117029  Condition: New: A brand-new, unused, unopened ...
# 121006  1.HIGH QUALITY: This Stylish Sling Bag Is Made...
# 123805  Hello there! Welcome to my store, if you like ...
# 126913  Welcome to Our Store!\nOur Products are 100% B...
# 127905  Phone Case for iPhone-5 5S SE-6 6S 7 8 Plus-X ...
# 129552  Phone Case for iPhone-5 5S SE-6 6S 7 8 Plus-X ...
# 131911  ***Rubber sole\n↘ "Just So So" symbol cool and...
# 135760  1.HIGH QUALITY: This Stylish Sling Bag Is Made...
# 177597  100% Brand New And High Quality\nMetal:Elephan...
# 200775  Title\nPortable Air Inflatable Travel Pillow C...
# 203131  HIGH QUALITY SLIPER SOCKS -- women winter sock...
#
#                                            main_image_url  \
# 47874   https://canary.contestimg.wish.com/api/webimag...
# 114291                                                NaN
# 114663  https://canary.contestimg.wish.com/api/webimag...
# 115076  https://canary.contestimg.wish.com/api/webimag...
# 117029                                                NaN
# 121006                                                NaN
# 123805                                                NaN
# 126913  https://canary.contestimg.wish.com/api/webimag...
# 127905  https://canary.contestimg.wish.com/api/webimag...
# 129552                                                NaN
# 131911                                                NaN
# 135760                                                NaN
# 177597  https://canary.contestimg.wish.com/api/webimag...
# 200775  https://canary.contestimg.wish.com/api/webimag...
# 203131  https://canary.contestimg.wish.com/api/webimag...
#
#                                          product_category  \
# 47874   Sports > Fishing > Fishing Apparel > Fishing V...
# 114291                      Jewelry & Accessories > Rings
# 114663  Consumer Electronics > Earphones & Headphones ...
# 115076            Luggage & Bags > Men's Bags > Backpacks
# 117029  Home & Garden > Arts, Crafts & Sewing > Leathe...
# 121006            Luggage & Bags > Men's Bags > Backpacks
# 123805                      Jewelry & Accessories > Rings
# 126913                      Jewelry & Accessories > Rings
# 127905  Cellphones & Telecommunications > Phone Bags &...
# 129552  Cellphones & Telecommunications > Phone Bags &...
# 131911                  Sports > Sneakers > Running Shoes
# 135760          Luggage & Bags > Men's Bags > Waist Packs
# 177597                      Jewelry & Accessories > Rings
# 200775           Sports > Camping & Hiking > Camping Mats
# 203131  Sports > Camping & Hiking > Hiking Clothing > ...
#
#                                               l2_category  no_attributes  \
# 47874                                   Sports > Fishing             NaN
# 114291                      Jewelry & Accessories > Rings            NaN
# 114663     Consumer Electronics > Earphones & Headphones             NaN
# 115076                       Luggage & Bags > Men's Bags             NaN
# 117029             Home & Garden > Arts, Crafts & Sewing             NaN
# 121006                       Luggage & Bags > Men's Bags             NaN
# 123805                      Jewelry & Accessories > Rings            NaN
# 126913                      Jewelry & Accessories > Rings            NaN
# 127905  Cellphones & Telecommunications > Phone Bags &...            NaN
# 129552  Cellphones & Telecommunications > Phone Bags &...            NaN
# 131911                                 Sports > Sneakers             NaN
# 135760                       Luggage & Bags > Men's Bags             NaN
# 177597                      Jewelry & Accessories > Rings            NaN
# 200775                         Sports > Camping & Hiking             NaN
# 203131                         Sports > Camping & Hiking             NaN
#
#        unlisted_value  ... rater3_unlisted_value  \
# 47874             NaN  ...                   NaN
# 114291            NaN  ...                   NaN
# 114663            NaN  ...                   NaN
# 115076            NaN  ...                   NaN
# 117029            NaN  ...                  True
# 121006            NaN  ...                   NaN
# 123805            NaN  ...                   NaN
# 126913            NaN  ...                   NaN
# 127905            NaN  ...                   NaN
# 129552            NaN  ...                   NaN
# 131911            NaN  ...                   NaN
# 135760            NaN  ...                  True
# 177597            NaN  ...                   NaN
# 200775            NaN  ...                  True
# 203131            NaN  ...                   NaN
#
#                                            title_original  \
# 47874   ​Lixada Breathable  Fishing Life Vest  209lb B...
# 114291                                                NaN
# 114663                                                NaN
# 115076                                                NaN
# 117029                                                NaN
# 121006                                                NaN
# 123805                                                NaN
# 126913                                                NaN
# 127905                                                NaN
# 129552                                                NaN
# 131911                                                NaN
# 135760                                                NaN
# 177597                                                NaN
# 200775                                                NaN
# 203131                                                NaN
#
#                                              final_output  \
# 47874   Sports > Fishing > Fishing Apparel > Fishing V...
# 114291                                                NaN
# 114663                                                NaN
# 115076                                                NaN
# 117029                                                NaN
# 121006                                                NaN
# 123805                                                NaN
# 126913                                                NaN
# 127905                                                NaN
# 129552                                                NaN
# 131911                                                NaN
# 135760                                                NaN
# 177597                                                NaN
# 200775                                                NaN
# 203131                                                NaN
#
#        product_description_original category_path explanation  \
# 47874                           NaN           NaN         NaN
# 114291                          NaN           NaN         NaN
# 114663                          NaN           NaN         NaN
# 115076                          NaN           NaN         NaN
# 117029                          NaN           NaN         NaN
# 121006                          NaN           NaN         NaN
# 123805                          NaN           NaN         NaN
# 126913                          NaN           NaN         NaN
# 127905                          NaN           NaN         NaN
# 129552                          NaN           NaN         NaN
# 131911                          NaN           NaN         NaN
# 135760                          NaN           NaN         NaN
# 177597                          NaN           NaN         NaN
# 200775                          NaN           NaN         NaN
# 203131                          NaN           NaN         NaN
#
#        final_output_corrected  \
# 47874                     NaN
# 114291                    NaN
# 114663                    NaN
# 115076                    NaN
# 117029                    NaN
# 121006                    NaN
# 123805                    NaN
# 126913                    NaN
# 127905                    NaN
# 129552                    NaN
# 131911                    NaN
# 135760                    NaN
# 177597                    NaN
# 200775                    NaN
# 203131                    NaN
#
#                                           title_original2  \
# 47874   ​Lixada Breathable  Fishing Life Vest  209lb B...
# 114291  ​​American Europe Women's Fashion Jewelry Anti...
# 114663  Apple AirPods with Wireless Charging Case ‎MRX...
# 115076  Blue Wolf Dream Catcher Chest Pack Unisex Slin...
# 117029  ​ 7x Leather Craft Half-Round Strap Belt End P...
# 121006  Hexagram Chest Pack Unisex Sling Backpack Casu...
# 123805  'Fear Nothing' Hip Hop Men's Fashion 925 Sterl...
# 126913     'Freedom or Death' Mens Punk Gothic Skull Ring
# 127905  Roses Are Red Doritos Are Savory The Us zfd Ph...
# 129552  Thin Red Line Union Jack Uk Flag ysf Phone Cas...
# 131911  'JUST SO SO' Breathable UNISEX Running Shoes |...
# 135760  Cock Chest Pack Unisex Sling Backpack Casual T...
# 177597  -Bold Filigree Thumb Wide Band, Statement Ring...
# 200775  - Inflating Pillows Ultralight Travel/Camping ...
# 203131                                  - Christmas socks
#
#                             product_description_original2  \
# 47874   This fishing Life jacket looks more like an ou...
# 114291  Stone: Moonstone\nColor: silver\nSize (US): 5 ...
# 114663  Feature:\nLatest and best AirPod\n\nLighting c...
# 115076  1.HIGH QUALITY: This Stylish Sling Bag Is Made...
# 117029  Condition: New: A brand-new, unused, unopened ...
# 121006  1.HIGH QUALITY: This Stylish Sling Bag Is Made...
# 123805  Hello there! Welcome to my store, if you like ...
# 126913  Welcome to Our Store!\nOur Products are 100% B...
# 127905  Phone Case for iPhone-5 5S SE-6 6S 7 8 Plus-X ...
# 129552  Phone Case for iPhone-5 5S SE-6 6S 7 8 Plus-X ...
# 131911  ***Rubber sole\n↘ "Just So So" symbol cool and...
# 135760  1.HIGH QUALITY: This Stylish Sling Bag Is Made...
# 177597  100% Brand New And High Quality\nMetal:Elephan...
# 200775  Title\nPortable Air Inflatable Travel Pillow C...
# 203131  HIGH QUALITY SLIPER SOCKS -- women winter sock...
#
#                                  main_image_url_original2
# 47874   https://canary.contestimg.wish.com/api/webimag...
# 114291                                                NaN
# 114663  https://canary.contestimg.wish.com/api/webimag...
# 115076  https://canary.contestimg.wish.com/api/webimag...
# 117029                                                NaN
# 121006                                                NaN
# 123805                                                NaN
# 126913  https://canary.contestimg.wish.com/api/webimag...
# 127905  https://canary.contestimg.wish.com/api/webimag...
# 129552                                                NaN
# 131911                                                NaN
# 135760                                                NaN
# 177597  https://canary.contestimg.wish.com/api/webimag...
# 200775  https://canary.contestimg.wish.com/api/webimag...
# 203131  https://canary.contestimg.wish.com/api/webimag...
#
# [15 rows x 29 columns]

# %%
df_uniq_merge[df_uniq_merge.product_description.apply(lambda x: str(x).strip()) != \
              df_uniq_merge.product_description_original2.apply(lambda x: str(x).strip())]
# Out:
#         label_ordering sample_method                product_id  \
# 3313             51483     only_text  6123bb20aeda2cbd38895710
# 3340             59846     only_text  614b380bd929bc0c71e48e9a
# 3342             60762     only_text  614e80e4095482726a25f9f2
# 3348             62151     only_text  600e79ace4f17152ae3331db
# 3350             62186     only_text  619f669a6e15952d0fd2d772
# ...                ...           ...                       ...
# 226485          249898  text_and_img  60e3db7b81b0ff8f96a27932
# 227561          250982  text_and_img  600bdb6a71ed47f3a9cecefa
# 238606           12731     only_text  617acc66258133f181049a30
# 240240          175412  text_and_img  62cfc691a029a596a5a292dd
# 240542           42251  text_and_img  618078fd270424b4aa7b9daf
#
#                                                     title  \
# 3313    Chihuahua Dog Night Light Cute Puppy Plug-in L...
# 3340    Amplificatore di segnale 2G 3G 4G GSM902 Cellu...
# 3342    LED Grow Lamp Adjustable Energy-saving  Wide A...
# 3348    2021 NEWEST Flower Pots Plant Basket with Hand...
# 3350    138 LED Star Moon Curtain String Lights 8 Mode...
# ...                                                   ...
# 226485  Raindrops Diet Coke For iPhone Case 12 11 Pro ...
# 227561  Michael Jordan Last Shot For iPhone Case 12 11...
# 238606  ZUCKEO 10W Low Voltage Landscape Lights LED La...
# 240240  Modern RGB Corner Floor Lamp LED Color Changin...
# 240542  Wack O Wax Halloween Candy (5 Pack) Vampire Te...
#
#                                       product_description  \
# 3313    Internal high-brightness LED. Bright enough to...
# 3340    welcome to my store!\n\n Features:\n - Full-du...
# 3342    Specifications: \nIt is the grow lamp that can...
# 3348    Feature:\n\n[Pure natural materials] It is art...
# 3350    welcome to my store!\n\nTips:Pls choose the co...
# ...                                                   ...
# 226485                                             #NAME?
# 227561                                             #NAME?
# 238606  body {\n  font-family: "Source Sans Pro", sans...
# 240240  Features:\n【Dimmable Floor Lights】RGB Corner F...
# 240542  body {\n  font-family: "Source Sans Pro", sans...
#
#                                            main_image_url  \
# 3313                                                  NaN
# 3340                                                  NaN
# 3342                                                  NaN
# 3348                                                  NaN
# 3350                                                  NaN
# ...                                                   ...
# 226485  https://canary.contestimg.wish.com/api/webimag...
# 227561  https://canary.contestimg.wish.com/api/webimag...
# 238606                                                NaN
# 240240  https://canary.contestimg.wish.com/api/webimag...
# 240542  https://canary.contestimg.wish.com/api/webimag...
#
#                                          product_category  \
# 3313    Home & Garden > Festive & Party Supplies > Eve...
# 3340    Cellphones & Telecommunications > Mobile Phone...
# 3342    Home & Garden > Garden Supplies > Indoor Garde...
# 3348    Home & Garden > Home Storage & Organization > ...
# 3350    Home Improvement > Lights & Lighting > LED Lig...
# ...                                                   ...
# 226485  Cellphones & Telecommunications > Phone Bags &...
# 227561  Cellphones & Telecommunications > Phone Bags &...
# 238606  Home Improvement > Lights & Lighting > Outdoor...
# 240240  Home Improvement > Lights & Lighting > Lamps &...
# 240542  Home & Garden > Festive & Party Supplies > Eve...
#
#                                               l2_category  no_attributes  \
# 3313            Home & Garden > Festive & Party Supplies             NaN
# 3340    Cellphones & Telecommunications > Mobile Phone...            NaN
# 3342                     Home & Garden > Garden Supplies             NaN
# 3348         Home & Garden > Home Storage & Organization             NaN
# 3350                Home Improvement > Lights & Lighting             NaN
# ...                                                   ...            ...
# 226485  Cellphones & Telecommunications > Phone Bags &...            NaN
# 227561  Cellphones & Telecommunications > Phone Bags &...            NaN
# 238606               Home Improvement > Lights & Lighting            NaN
# 240240              Home Improvement > Lights & Lighting             NaN
# 240542           Home & Garden > Festive & Party Supplies            NaN
#
#        unlisted_value  ... rater3_unlisted_value  \
# 3313              NaN  ...                   NaN
# 3340             True  ...                   NaN
# 3342             True  ...                   NaN
# 3348              NaN  ...                   NaN
# 3350              NaN  ...                   NaN
# ...               ...  ...                   ...
# 226485            NaN  ...                  True
# 227561            NaN  ...                  True
# 238606            NaN  ...                   NaN
# 240240            NaN  ...                   NaN
# 240542            NaN  ...                  True
#
#                                            title_original  \
# 3313                                                  NaN
# 3340                                                  NaN
# 3342                                                  NaN
# 3348                                                  NaN
# 3350                                                  NaN
# ...                                                   ...
# 226485                                                NaN
# 227561                                                NaN
# 238606  ZUCKEO 10W Low Voltage Landscape Lights LED La...
# 240240  Modern RGB Corner Floor Lamp LED Color Changin...
# 240542  Wack O Wax Halloween Candy (5 Pack) Vampire Te...
#
#                                              final_output  \
# 3313                                                  NaN
# 3340                                                  NaN
# 3342                                                  NaN
# 3348                                                  NaN
# 3350                                                  NaN
# ...                                                   ...
# 226485                                                NaN
# 227561                                                NaN
# 238606  \nHome Improvement > Lights & Lighting > Outdo...
# 240240  Home Improvement > Lights & Lighting > Lamps &...
# 240542  Home & Garden > Festive & Party Supplies > Eve...
#
#        product_description_original category_path  \
# 3313                            NaN           NaN
# 3340                            NaN           NaN
# 3342                            NaN           NaN
# 3348                            NaN           NaN
# 3350                            NaN           NaN
# ...                             ...           ...
# 226485                          NaN           NaN
# 227561                          NaN           NaN
# 238606                          NaN           NaN
# 240240                          NaN           NaN
# 240542                          NaN           NaN
#
#                                               explanation  \
# 3313                                                  NaN
# 3340                                                  NaN
# 3342                                                  NaN
# 3348                                                  NaN
# 3350                                                  NaN
# ...                                                   ...
# 226485                                                NaN
# 227561                                                NaN
# 238606  Home Improvement > Lights & Lighting > Outdoor...
# 240240  Home Improvement > Lights & Lighting > Lamps &...
# 240542  Home & Garden > Festive & Party Supplies > Eve...
#
#                                    final_output_corrected  \
# 3313                                                  NaN
# 3340                                                  NaN
# 3342                                                  NaN
# 3348                                                  NaN
# 3350                                                  NaN
# ...                                                   ...
# 226485                                                NaN
# 227561                                                NaN
# 238606  Home Improvement > Lights & Lighting > Outdoor...
# 240240  Home Improvement > Lights & Lighting > Lamps &...
# 240542  Home & Garden > Festive & Party Supplies > Eve...
#
#                                           title_original2  \
# 3313    Chihuahua Dog Night Light Cute Puppy Plug-in L...
# 3340    Amplificatore di segnale 2G 3G 4G GSM902 Cellu...
# 3342      LED Grow Lamp Adjustable Energy-saving  Wide...
# 3348    2021 NEWEST Flower Pots Plant Basket with Hand...
# 3350    138 LED Star Moon Curtain String Lights 8 Mode...
# ...                                                   ...
# 226485  Raindrops Diet Coke For iPhone Case 12 11 Pro ...
# 227561  Michael Jordan Last Shot For iPhone Case 12 11...
# 238606  ZUCKEO 10W Low Voltage Landscape Lights LED La...
# 240240  Modern RGB Corner Floor Lamp LED Color Changin...
# 240542  Wack O Wax Halloween Candy (5 Pack) Vampire Te...
#
#                             product_description_original2  \
# 3313    Internal high-brightness LED. Bright enough to...
# 3340    welcome to my store!\r\n\r\n Features:\n - Ful...
# 3342    Specifications: \nIt is the grow lamp that can...
# 3348    Feature:\r\n\r\n[Pure natural materials] It is...
# 3350    welcome to my store!\r\n\r\nTips:Pls choose th...
# ...                                                   ...
# 226485  - Material: Made from high-quality plate and r...
# 227561  - Material: Made from high-quality plate and r...
# 238606  body {\n  font-family: "Source Sans Pro", sans...
# 240240  \nFeatures:\n【Dimmable Floor Lights】RGB Corner...
# 240542  body {\n  font-family: "Source Sans Pro", sans...
#
#                                  main_image_url_original2
# 3313                                                  NaN
# 3340                                                  NaN
# 3342                                                  NaN
# 3348                                                  NaN
# 3350                                                  NaN
# ...                                                   ...
# 226485  https://canary.contestimg.wish.com/api/webimag...
# 227561  https://canary.contestimg.wish.com/api/webimag...
# 238606                                                NaN
# 240240  https://canary.contestimg.wish.com/api/webimag...
# 240542  https://canary.contestimg.wish.com/api/webimag...
#
# [9134 rows x 29 columns]

# %%
df_uniq_merge[df_uniq_merge.main_image_url.apply(lambda x: str(x).strip()) != \
              df_uniq_merge.main_image_url_original2.apply(lambda x: str(x).strip())]
# Out:
# Empty DataFrame
# Columns: [label_ordering, sample_method, product_id, title, product_description, main_image_url, product_category, l2_category, no_attributes, unlisted_value, rater3_output, file_name, rater1_no_attributes, rater1_unlisted_value, rater1_output, rater2_no_attributes, rater2_unlisted_value, rater2_output, rater3_no_attributes, rater3_unlisted_value, title_original, final_output, product_description_original, category_path, explanation, final_output_corrected, title_original2, product_description_original2, main_image_url_original2]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_uniq_merge[df_uniq_merge.main_image_url.apply(lambda x: str(x).strip()) != \
              df_uniq_merge.main_image_url_original2.apply(lambda x: str(x).strip())]
# Out:
# Empty DataFrame
# Columns: [label_ordering, sample_method, product_id, title, product_description, main_image_url, product_category, l2_category, no_attributes, unlisted_value, rater3_output, file_name, rater1_no_attributes, rater1_unlisted_value, rater1_output, rater2_no_attributes, rater2_unlisted_value, rater2_output, rater3_no_attributes, rater3_unlisted_value, title_original, final_output, product_description_original, category_path, explanation, final_output_corrected, title_original2, product_description_original2, main_image_url_original2]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_uniq_merge['title'] = df_uniq_merge['title_original2']
df_uniq_merge['product_description'] = df_uniq_merge['product_description_original2']

# %%
df_uniq_merge[df_uniq_merge.title.isna()]
# Out:
# Empty DataFrame
# Columns: [label_ordering, sample_method, product_id, title, product_description, main_image_url, product_category, l2_category, no_attributes, unlisted_value, rater3_output, file_name, rater1_no_attributes, rater1_unlisted_value, rater1_output, rater2_no_attributes, rater2_unlisted_value, rater2_output, rater3_no_attributes, rater3_unlisted_value, title_original, final_output, product_description_original, category_path, explanation, final_output_corrected, title_original2, product_description_original2, main_image_url_original2]
# Index: []
#
# [0 rows x 29 columns]

# %%
df_uniq_merge[df_uniq_merge.product_description.isna()]
# Out:
#       label_ordering sample_method                product_id  \
# 1579           35818  text_and_img  6120aa90d631eeaff38fd328
#
#                                                   title product_description  \
# 1579  3 Style New Concept Training Hidden Happiness Cup                 NaN
#
#                                          main_image_url  \
# 1579  https://canary.contestimg.wish.com/api/webimag...
#
#                                        product_category  \
# 1579  Home & Garden > Kitchen,Dining & Bar > Teaware...
#
#                                 l2_category  no_attributes unlisted_value  \
# 1579  Home & Garden > Kitchen,Dining & Bar             NaN            NaN
#
#       ... rater3_unlisted_value title_original final_output  \
# 1579  ...                   NaN            NaN          NaN
#
#      product_description_original category_path explanation  \
# 1579                          NaN           NaN         NaN
#
#      final_output_corrected  \
# 1579                    NaN
#
#                                         title_original2  \
# 1579  3 Style New Concept Training Hidden Happiness Cup
#
#      product_description_original2  \
# 1579                           NaN
#
#                                main_image_url_original2
# 1579  https://canary.contestimg.wish.com/api/webimag...
#
# [1 rows x 29 columns]

# %%
df_uniq_merge.loc[df_uniq_merge.product_description.isna(), 'product_description'] = ''

# %%
set(df_uniq_merge)
# Out:
# {'category_path',
#  'explanation',
#  'file_name',
#  'final_output',
#  'final_output_corrected',
#  'l2_category',
#  'label_ordering',
#  'main_image_url',
#  'main_image_url_original2',
#  'no_attributes',
#  'product_category',
#  'product_description',
#  'product_description_original',
#  'product_description_original2',
#  'product_id',
#  'rater1_no_attributes',
#  'rater1_output',
#  'rater1_unlisted_value',
#  'rater2_no_attributes',
#  'rater2_output',
#  'rater2_unlisted_value',
#  'rater3_no_attributes',
#  'rater3_output',
#  'rater3_unlisted_value',
#  'sample_method',
#  'title',
#  'title_original',
#  'title_original2',
#  'unlisted_value'}

# %%
df_uniq_merge['final_output'] = df_uniq_merge['rater1_output'].fillna('') + '\n' + df_uniq_merge['rater2_output'].fillna('') + '\n' + \
    df_uniq_merge['rater3_output'].fillna('')

# %%
df_uniq_merge.loc[~df_uniq_merge.final_output_corrected.isna(), 'final_output'] = \
    df_uniq_merge.loc[~df_uniq_merge.final_output_corrected.isna(), 'final_output_corrected']

# %%
len(df_uniq_merge), len(set(df_uniq_merge.label_ordering))
# Out:
# (240673, 240673)

# %%
df_uniq_merge[df_uniq_merge.final_output.isna()]
# Out:
# Empty DataFrame
# Columns: [label_ordering, sample_method, product_id, title, product_description, main_image_url, product_category, l2_category, no_attributes, unlisted_value, rater3_output, file_name, rater1_no_attributes, rater1_unlisted_value, rater1_output, rater2_no_attributes, rater2_unlisted_value, rater2_output, rater3_no_attributes, rater3_unlisted_value, title_original, final_output, product_description_original, category_path, explanation, final_output_corrected, title_original2, product_description_original2, main_image_url_original2]
# Index: []
#
# [0 rows x 29 columns]

# %%
correct = []
errors = []
errors_fixed = []
nonempty = []
empty = []
for i in df_uniq_merge.to_dict('records'):
    res = [] if ((not isinstance(i['final_output'], str)) and (np.isnan(i['final_output']))) else i['final_output'].split('\n')
    res = sorted(set(res))
    res = [i for i in res if len(i) > 0]
    if len(res) == 0:
        empty.append(i)
    is_correct = True
    for j in res:
        if len(j.split(' > ')) < 2:
            i['explanation'] = f"{j} has no attribute name"
            errors.append(i)
            is_correct = False
            break
        if j.split(' > ')[-2] not in attributes:
            i['explanation'] = f"{j} has invalid attribute name, because {j.split(' > ')[-2]} is not a valid attribute name"
            errors.append(i)
            is_correct = False
            break
    if is_correct:
        correct.append(i)
        if len(res) > 0:
            nonempty.append(i)
for i in errors:
    res = [] if ((not isinstance(i['final_output'], str)) and (np.isnan(i['final_output']))) else i['final_output'].split('\n')
    res = sorted(set(res))
    res = [i for i in res if len(i) > 0]
    corrected_res = []
    for j in res:
        if len(j.split(' > ')) >= 2 and j.split(' > ')[-2] in attributes:
            corrected_res.append(j)
    i['final_output_corrected'] = '\n'.join(corrected_res)
    errors_fixed.append(i)

len(df_uniq_merge), len(correct), len(errors), len(errors_fixed), len(empty), len(nonempty), len(correct) + len(errors)
# Out:
# (240673, 239596, 1077, 1077, 0, 239596, 240673)

# %%
df_error_fixed = pd.DataFrame(errors_fixed)

# %%
df_error_fixed['final_output_corrected'].apply(lambda x: len(x) == 0).mean()
# Out:
# 0.013927576601671309

# %%
df_error_fixed_nonempty = df_error_fixed[df_error_fixed['final_output_corrected'].apply(lambda x: len(x) > 0)]
df_error_fixed_empty = df_error_fixed[df_error_fixed['final_output_corrected'].apply(lambda x: len(x) == 0)]

# %%
len(df_error_fixed_empty)
# Out:
# 15

# %%
df_error_fixed_empty
# Out:
#       label_ordering sample_method                product_id  \
# 1062           24297     only_text  611bb00e2522356ea1aac345
# 1063           25950     only_text  6011c26b367389cfe64dc2c0
# 1064           34429  text_and_img  60336e08b4e87ed4251e8e65
# 1065           37053     only_text  60116692795639f1b27eec1c
# 1066           37147     only_text  6187a85807a1cbdb0eeb99f2
# 1067           38050     only_text  60dd8710a21dd0c4c074030e
# 1068           38982     only_text  6176149778dc188427553c38
# 1069           39384     only_text  604e464a5b9ef6005771cc22
# 1070           41946  text_and_img  5ff4261a407f5715cc56a273
# 1071           42001     only_text  618f60c807486a158cdc5a1d
# 1072           48049  text_and_img  615c24441ab6ae3249e0155c
# 1073           50243     only_text  60c44c0a972fbbb19692d7c4
# 1074           55267     only_text  5ff7561314f4bce51e94bec3
# 1075           15280     only_text  60ae5e332bfa01f072e2ac36
# 1076           16306     only_text  613289bf42f12c26b1a493fe
#
#                                                   title  \
# 1062   1 Set Helpful Butter Box Large Capacity Seale...
# 1063  Honeybee Gardens Wanderlust PowderColors Stack...
# 1064                                      [BEST SELLER]
# 1065  AHC Natural Perfection Double Shield Enthusias...
# 1066                              Ridgid 632-45260 Pins
# 1067  New emergency sleeping bag thermal insulation ...
# 1068  Carburetor Gaskets Kit For RY3714 & RY3716 Cha...
# 1069  Night to remember standard 6.5in napkins (10 p...
# 1070        Geoffrey Art Handmade Name Necklace Jewelry
# 1071  Plaid Letter Leather Phone Protective Case for...
# 1072  100Pcs 4.72Inch Butterfly Toothpicks Food Pick...
# 1073  Daddy Shoes Summer Breathable 2021 New Thick-s...
# 1074  Pet Nylon Tactical Waterproof Strap Medium and...
# 1075  Mouse Pieces of Cheese Night Light Plug in Set...
# 1076                Dr.505 Atocle Solution 3 Set, 1 Set
#
#                                     product_description  \
# 1062  Specifications: \nThis sealed box cutting set ...
# 1063  undefined\n\n\nColor × Quantity-See details × ...
# 1064  ● Kerr Jars Mason Wide Mouth with Cap Quart 12...
# 1065  undefined\n\n\nCapacity-1. Enthusiastic Sun St...
# 1066  Ridgid 632-45260 Pins-We do not ship to PO BOX...
# 1067  Dear customers:\nWelcome to our store, you wil...
# 1068  Condition: New\nBrand: Unbranded\nType: Carb K...
# 1069  Its ladies night any night with Night to Remem...
# 1070  Geoffrey Art Handmade Name Necklace Jewelry Ch...
# 1071  100% Brand New and High Quality\n\nPackage inc...
# 1072  Description:\n100% Brand New and High quality....
# 1073  Year and season of listing: Summer 2021. Top m...
# 1074  Material : 1000d Nylon\r\nProduct Category : P...
# 1075  This LED Sensor Night Light Is Powered By Brig...
# 1076  Expiration date (use-by-date for products subj...
#
#                                          main_image_url  \
# 1062                                                NaN
# 1063                                                NaN
# 1064  https://canary.contestimg.wish.com/api/webimag...
# 1065                                                NaN
# 1066                                                NaN
# 1067                                                NaN
# 1068                                                NaN
# 1069                                                NaN
# 1070  https://canary.contestimg.wish.com/api/webimag...
# 1071                                                NaN
# 1072  https://canary.contestimg.wish.com/api/webimag...
# 1073                                                NaN
# 1074                                                NaN
# 1075                                                NaN
# 1076                                                NaN
#
#                                        product_category  \
# 1062                                                NaN
# 1063                                                NaN
# 1064                                                NaN
# 1065                                                NaN
# 1066                                                NaN
# 1067                                                NaN
# 1068                                                NaN
# 1069                                                NaN
# 1070                                                NaN
# 1071                                                NaN
# 1072                                                NaN
# 1073                                                NaN
# 1074  Sports > Hunting > Tactical Headsets & Accesso...
# 1075  Home & Garden > Festive & Party Supplies > Eve...
# 1076  Home & Garden > Pet Products > Pet Medical Sup...
#
#                                    l2_category  no_attributes  unlisted_value  \
# 1062                                       NaN            NaN             NaN
# 1063                                       NaN            NaN             NaN
# 1064                                       NaN            NaN             NaN
# 1065                                       NaN            NaN             NaN
# 1066                                       NaN            NaN             NaN
# 1067                                       NaN            NaN             NaN
# 1068                                       NaN            NaN             NaN
# 1069                                       NaN            NaN             NaN
# 1070                                       NaN            NaN             NaN
# 1071                                       NaN            NaN             NaN
# 1072                                       NaN            NaN             NaN
# 1073                                       NaN            NaN             NaN
# 1074                         Sports > Hunting             NaN             NaN
# 1075  Home & Garden > Festive & Party Supplies            NaN             NaN
# 1076              Home & Garden > Pet Products            NaN             NaN
#
#       ... rater3_unlisted_value  \
# 1062  ...                     0
# 1063  ...                     0
# 1064  ...                     0
# 1065  ...                     0
# 1066  ...                     0
# 1067  ...                     0
# 1068  ...                     0
# 1069  ...                     0
# 1070  ...                     0
# 1071  ...                     0
# 1072  ...                     0
# 1073  ...                     0
# 1074  ...                   NaN
# 1075  ...                   NaN
# 1076  ...                   NaN
#
#                                          title_original  \
# 1062   1 Set Helpful Butter Box Large Capacity Seale...
# 1063  Honeybee Gardens Wanderlust PowderColors Stack...
# 1064                                      [BEST SELLER]
# 1065  AHC Natural Perfection Double Shield Enthusias...
# 1066                              Ridgid 632-45260 Pins
# 1067  New emergency sleeping bag thermal insulation ...
# 1068  Carburetor Gaskets Kit For RY3714 & RY3716 Cha...
# 1069  Night to remember standard 6.5in napkins (10 p...
# 1070        Geoffrey Art Handmade Name Necklace Jewelry
# 1071  Plaid Letter Leather Phone Protective Case for...
# 1072  100Pcs 4.72Inch Butterfly Toothpicks Food Pick...
# 1073  Daddy Shoes Summer Breathable 2021 New Thick-s...
# 1074  Pet Nylon Tactical Waterproof Strap Medium and...
# 1075  Mouse Pieces of Cheese Night Light Plug in Set...
# 1076                Dr.505 Atocle Solution 3 Set, 1 Set
#
#                                            final_output  \
# 1062                                            0\n0\n0
# 1063                                            0\n0\n0
# 1064                                            0\n0\n0
# 1065                                            0\n0\n0
# 1066                                            0\n0\n0
# 1067                                            0\n0\n0
# 1068                                            0\n0\n0
# 1069                                            0\n0\n0
# 1070                                            0\n0\n0
# 1071                                            0\n0\n0
# 1072                                            0\n0\n0
# 1073                                            0\n0\n0
# 1074  Sports > Hunting > Tactical Headsets & Accesso...
# 1075  \nHome & Garden > Festive & Party Supplies > E...
# 1076  Home & Garden > Pet Products > Pet Medical Sup...
#
#                            product_description_original  \
# 1062  Specifications: \nThis sealed box cutting set ...
# 1063  undefined\n\n\nColor × Quantity-See details × ...
# 1064  ● Kerr Jars Mason Wide Mouth with Cap Quart 12...
# 1065  undefined\n\n\nCapacity-1. Enthusiastic Sun St...
# 1066  Ridgid 632-45260 Pins-We do not ship to PO BOX...
# 1067  Dear customers:\nWelcome to our store, you wil...
# 1068  Condition: New\nBrand: Unbranded\nType: Carb K...
# 1069  Its ladies night any night with Night to Remem...
# 1070  Geoffrey Art Handmade Name Necklace Jewelry Ch...
# 1071  100% Brand New and High Quality\n\nPackage inc...
# 1072  Description:\n100% Brand New and High quality....
# 1073  Year and season of listing: Summer 2021. Top m...
# 1074  Material : 1000d Nylon\r\nProduct Category : P...
# 1075                                                NaN
# 1076                                                NaN
#
#                                           category_path  \
# 1062  Home & Garden > Kitchen,Dining & Bar > Cheese ...
# 1063  Home & Garden > Garden Supplies > Yard & Garde...
# 1064  Home & Garden > Home Storage & Organization > ...
# 1065         Sports > Camping & Hiking > Walking Sticks
# 1066  Cellphones & Telecommunications > Mobile Phone...
# 1067  Sports > Camping & Hiking > Camp Sleeping Gear...
# 1068     Home & Garden > Garden Supplies > Garden Carts
# 1069  Home & Garden > Kitchen,Dining & Bar > Disposa...
# 1070  Jewelry & Accessories > Necklaces & Pendants >...
# 1071  Cellphones & Telecommunications > Phone Bags &...
# 1072  Home & Garden > Kitchen,Dining & Bar > Flatwar...
# 1073                 Shoes > Women's Shoes > Boat Shoes
# 1074                                                NaN
# 1075                                                NaN
# 1076                                                NaN
#
#                                             explanation  \
# 1062                            0 has no attribute name
# 1063                            0 has no attribute name
# 1064                            0 has no attribute name
# 1065                            0 has no attribute name
# 1066                            0 has no attribute name
# 1067                            0 has no attribute name
# 1068                            0 has no attribute name
# 1069                            0 has no attribute name
# 1070                            0 has no attribute name
# 1071                            0 has no attribute name
# 1072                            0 has no attribute name
# 1073                            0 has no attribute name
# 1074  Sports > Hunting > Tactical Headsets & Accesso...
# 1075  Home & Garden > Festive & Party Supplies > Eve...
# 1076  Home & Garden > Pet Products > Pet Medical Sup...
#
#      final_output_corrected  \
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
#
#                                         title_original2  \
# 1062   1 Set Helpful Butter Box Large Capacity Seale...
# 1063  Honeybee Gardens Wanderlust PowderColors Stack...
# 1064                                      [BEST SELLER]
# 1065  AHC Natural Perfection Double Shield Enthusias...
# 1066                              Ridgid 632-45260 Pins
# 1067  New emergency sleeping bag thermal insulation ...
# 1068  Carburetor Gaskets Kit For RY3714 & RY3716 Cha...
# 1069  Night to remember standard 6.5in napkins (10 p...
# 1070        Geoffrey Art Handmade Name Necklace Jewelry
# 1071  Plaid Letter Leather Phone Protective Case for...
# 1072  100Pcs 4.72Inch Butterfly Toothpicks Food Pick...
# 1073  Daddy Shoes Summer Breathable 2021 New Thick-s...
# 1074  Pet Nylon Tactical Waterproof Strap Medium and...
# 1075  Mouse Pieces of Cheese Night Light Plug in Set...
# 1076                Dr.505 Atocle Solution 3 Set, 1 Set
#
#                           product_description_original2  \
# 1062  Specifications: \nThis sealed box cutting set ...
# 1063  undefined\n\n\nColor × Quantity-See details × ...
# 1064  ● Kerr Jars Mason Wide Mouth with Cap Quart 12...
# 1065  undefined\n\n\nCapacity-1. Enthusiastic Sun St...
# 1066  Ridgid 632-45260 Pins-We do not ship to PO BOX...
# 1067  Dear customers:\nWelcome to our store, you wil...
# 1068  Condition: New\nBrand: Unbranded\nType: Carb K...
# 1069  Its ladies night any night with Night to Remem...
# 1070  Geoffrey Art Handmade Name Necklace Jewelry Ch...
# 1071  100% Brand New and High Quality\n\nPackage inc...
# 1072  Description:\n100% Brand New and High quality....
# 1073  Year and season of listing: Summer 2021. Top m...
# 1074  Material : 1000d Nylon\r\nProduct Category : P...
# 1075  This LED Sensor Night Light Is Powered By Brig...
# 1076  Expiration date (use-by-date for products subj...
#
#                                main_image_url_original2
# 1062                                                NaN
# 1063                                                NaN
# 1064  https://canary.contestimg.wish.com/api/webimag...
# 1065                                                NaN
# 1066                                                NaN
# 1067                                                NaN
# 1068                                                NaN
# 1069                                                NaN
# 1070  https://canary.contestimg.wish.com/api/webimag...
# 1071                                                NaN
# 1072  https://canary.contestimg.wish.com/api/webimag...
# 1073                                                NaN
# 1074                                                NaN
# 1075                                                NaN
# 1076                                                NaN
#
# [15 rows x 29 columns]

# %%
df_correct = pd.DataFrame(correct)

# %%
df_correct['final_output'].apply(lambda x: len(x) == 0).mean()
# Out:
# 0.0

# %%
df_error_fixed_nonempty['final_output'] = df_error_fixed_nonempty['final_output_corrected']
# Out:
# /tmp/ipykernel_27105/1192569628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_error_fixed_nonempty['final_output'] = df_error_fixed_nonempty['final_output_corrected']

# %%
df_correct = pd.concat([df_correct, df_error_fixed_nonempty])

# %%
len(df_correct) / len(df_original)
# Out:
# 0.9974138145406619

# %%
len(df_correct), len(set(df_correct.label_ordering))
# Out:
# (240658, 240658)

# %%
df_error_fixed_empty['rater3_no_attributes'].all()
# Out:
# True

# %%
len(df_error_fixed_empty)
# Out:
# 15

# %%
set(df_error_fixed_empty.file_name)
# Out:
# {'product_attribution_just_032723_invalid_units_fixed.csv',
#  'product_attribution_missed_032423_just_032723_invalid_units_fixed.csv',
#  'product_attribution_till_032423_invalid_units_fixed.csv'}

# %%
set(df_correct)
# Out:
# {'category_path',
#  'explanation',
#  'file_name',
#  'final_output',
#  'final_output_corrected',
#  'l2_category',
#  'label_ordering',
#  'main_image_url',
#  'main_image_url_original2',
#  'no_attributes',
#  'product_category',
#  'product_description',
#  'product_description_original',
#  'product_description_original2',
#  'product_id',
#  'rater1_no_attributes',
#  'rater1_output',
#  'rater1_unlisted_value',
#  'rater2_no_attributes',
#  'rater2_output',
#  'rater2_unlisted_value',
#  'rater3_no_attributes',
#  'rater3_output',
#  'rater3_unlisted_value',
#  'sample_method',
#  'title',
#  'title_original',
#  'title_original2',
#  'unlisted_value'}

# %%
df_correct = df_correct[['label_ordering', 'sample_method', 'product_id', 'title', 'product_description', 'main_image_url', 'final_output']]

# %%
len(df_correct)
# Out:
# 240658

# %%
df_correct = df_correct.merge(df_original[['label_ordering', 'category_path']])

# %%
len(df_correct)
# Out:
# 240658

# %%
df_correct.sample(2).to_dict('records')
# Out:
# [{'label_ordering': 112800,
#   'sample_method': 'only_text',
#   'product_id': '60e55182d1df0820c446610f',
#   'title': '  Practical Insect Net Breathable Folding Insect Repellent Hanging Tent Lightweight   for Picnic  ',
#   'product_description': 'Specifications: \nWhat the fine mesh can offer is that can effectively prevent mosquito and insect from biting. Foldable storage and lightweight design make it easy to carry.\nBecause of the fine mesh, you can be protected from mosquito and insect from biting. Foldable storage and lightweight design make it easy to carry.\nYou can be protected from mosquito and insect from biting with the protection of the fine mesh net. This product is easy to carry with foldable storage and lightweight design.\nIt is easy to carry with foldable storage and lightweight design. It can effectively prevent mosquito and insect from biting since it has fine mesh.\nWith foldable storage and lightweight design, it is easy to carry. With the protection of the fine mesh net, the mosquito and insect can be completely blocked out of the tent.\n\nItem Name: Dome Mosquito Net\nMaterial : Polyester\n300cm x 230cm/118.11" x 90.55" (Approx.) \nCircumference: 950cm/374.02" (Approx.)\nNotes: \nDue to the light and screen setting difference, the item\'s color may be slightly different from the pictures.\r\nPlease allow slight dimension difference due to different manual measurement.\n\nPackage Includes: \n1 x Dome Mosquito Net',
#   'main_image_url': nan,
#   'final_output': 'Home & Garden > Home Textile > Bedding > Mosquito Nets > Materials > Polyester\nHome & Garden > Home Textile > Bedding > Mosquito Nets > Size > 300cm x 230cm\nHome & Garden > Home Textile > Bedding > Mosquito Nets > Materials > Polyester\nHome & Garden > Home Textile > Bedding > Mosquito Nets > Materials > Polyester\nHome & Garden > Home Textile > Bedding > Mosquito Nets > Size > 300cm x 230cm',
#   'category_path': 'Home & Garden > Home Textile > Bedding > Mosquito Nets'},
#  {'label_ordering': 217883,
#   'sample_method': 'text_and_img',
#   'product_id': '611c9b1531dd3e4df41b3485',
#   'title': 'Button badge - 1.5 in ( 37 mm ) - Apple',
#   'product_description': '37 mm ( 1.5 in ) Button Badge.\nThe colours of Button Badges may be a bit different than those shown on the monitor.\nButton Badges are printed in very high quality.',
#   'main_image_url': 'https://canary.contestimg.wish.com/api/webimage/611c9b1531dd3e4df41b3485-0-large.jpg',
#   'final_output': 'Home & Garden > Arts, Crafts & Sewing > Apparel Sewing & Fabric > Buttons > Primary Color > Red\nHome & Garden > Arts, Crafts & Sewing > Apparel Sewing & Fabric > Buttons > Alpha Size > 1.5 inch\nHome & Garden > Arts, Crafts & Sewing > Button & Badge Making > Button & Badge Parts > Primary Color > Red\nHome & Garden > Arts, Crafts & Sewing > Button & Badge Making > Button & Badge Parts > Primary Color > Beige\nHome & Garden > Arts, Crafts & Sewing > Apparel Sewing & Fabric > Buttons > Primary Color > Red',
#   'category_path': 'Home & Garden > Arts, Crafts & Sewing > Button & Badge Making > Button & Badge Parts'}]

# %%
df_correct.to_csv('appen/output_batch_correct_v10/product_attribution_till_041023_valid_units.csv', index=False)

# %%
len(set(df_correct.label_ordering))
# Out:
# 240658

# %%
len(set(df_original.label_ordering))
# Out:
# 241282

# %%
len(set(df_original.label_ordering)) - len(set(df_correct.label_ordering))
# Out:
# 624
