# %%
import pandas as pd

# %%
df = pd.read_json('size_10k_25l2_openai_0shot_pseudolabel.json', lines=True)

# %%
len(set(df.L2))
# Out:
# 25

# %%
df.L2.value_counts().plot.pie()
# Out:
# <AxesSubplot: ylabel='L2'>

# %%
df.L2.value_counts().mean(), df.L2.value_counts().std()
# Out:
# (262.48, 29.264768351495054)

# %%
df.openai0shot_attr.apply(len).min(), df.openai0shot_attr.apply(len).max(), df.openai0shot_attr.apply(len).mean()
# Out:
# (0, 33, 5.61139896373057)

# %%
df.openai0shot_attr.apply(len).plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.sample(1).to_dict('records')
# Out:
# [{'product_id': '612f1541b7977de8638b5deb',
#   'category_id': 6048,
#   'category_name': 'Dresses',
#   'category_path': "Women's Clothing > Dresses",
#   'L2': "Women's Clothing > Dresses",
#   'name': 'HOT Summer XL-5XL Knee HAOOHU Plus Size Dress Women Sleeveless T-Shirt Print Night Club Party Bandage Street Dresses Vestidos',
#   'product_description': 'Brand Name:HAOOHU\nMaterial:Polyester\nMaterial:Spandex\nSilhouette:Straight\nAge:Ages 18-35 Years Old\nSeason:Summer\nNeckline:V-Neck\nSleeve Length(cm):Short\nSleeve Style:Regular\nDecoration:Pockets\nStyle:Casual\nWaistline:Natural\nPattern Type:Print\nDresses Length:Knee-Length',
#   'num_extra_photos': 11,
#   'main_image_url': 'https://canary.contestimg.wish.com/api/webimage/612f1541b7977de8638b5deb-0-large.jpg',
#   'openai0shot_attr': {'Material type': ['Polyester', 'Spandex'],
#    'NeckStyle': 'V-Neck',
#    'Occasion Lifestyle': 'Casual',
#    'Pattern': 'Print',
#    'Size Map': 'XL-5XL',
# ...
