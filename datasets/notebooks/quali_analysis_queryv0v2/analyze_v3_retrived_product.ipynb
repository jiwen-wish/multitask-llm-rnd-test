# %%
import pandas as pd
import os

# %%
recs = []
for f in os.listdir('retrieved_products'):
    with open(f'retrieved_products/{f}', 'r') as fin:
        for i in fin:
            try:
                query = i.split(',"')[0]
                split = i.split(',"')[1].split('",')[0]
                products = eval(i.split(',"')[1].split('",')[1])
                recs.append({
                    'file': f, 
                    'query': query, 
                    'split': split, 
                    'products': products
                })
            except:
                pass
df = pd.DataFrame(recs)

# %%
df_group = df.groupby(['file', 'query']).agg({
    'split': lambda x: [i for i in x],
    'products': lambda x: [i for i in x]
}).reset_index()

# %%
df_group.split.apply(lambda x: x[0] == 'control').all()
# Out:
# True

# %%
def calc_jaccard(x, y):
    if len(x) == 0 or len(y) == 0:
        return 1. 
    else:
        return len(set(x).intersection(set(y))) / len(set(x).union(set(y)))

# %%
df_group['jaccard_top10'] = df_group['products'].apply(lambda x: calc_jaccard(x[0], x[1]))

# %%
df_group.jaccard_top10.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df_group[df_group['jaccard_top10'] < .5].file.value_counts().plot.pie()
# Out:
# <AxesSubplot: ylabel='file'>

# %%
df_group_sample = df_group[df_group['jaccard_top10'] < .2].groupby('file').sample(20, random_state=42)

# %%
df_group_sample
# Out:
#                           file                                query  \
# 1984    show_v1_head_x1000.csv                     US_1_woman dress
# 1021    show_v1_head_x1000.csv                         US_1_android
# 21      show_v1_head_x1000.csv                         US_0_android
# 984     show_v1_head_x1000.csv                     US_0_woman dress
# 2027    show_v1_head_x1000.csv                           US_2_apple
# ...                        ...                                  ...
# 13482  show_v2_torso_x1000.csv                 US_1_make up carrier
# 13354  show_v2_torso_x1000.csv                            US_1_gems
# 13054  show_v2_torso_x1000.csv                        US_1_atomiser
# 13829  show_v2_torso_x1000.csv             US_1_vhs player for sale
# 13329  show_v2_torso_x1000.csv  US_1_flight socks compression women
#
#                     split                                           products  \
# 1984   [control, show-v1]  [[60fe1d2ed25d8ff937972f32, 5e96f2272acfce091b...
# 1021   [control, show-v1]  [[63aaf4b98eead43909cb0527, 63b6d75f8b205e8fd7...
# 21     [control, show-v1]  [[63aaf4b98eead43909cb0527, 63b6d75f8b205e8fd7...
# 984    [control, show-v1]  [[5e96f2272acfce091bc80052, 60fe1d2ed25d8ff937...
# 2027   [control, show-v1]  [[5dd71a00dd0c38cb85a85e49, 5e1659e41df5f12940...
# ...                   ...                                                ...
# 13482  [control, show-v2]  [[60e81e5302d3fbb51330b8fe, 5fe9aee8d36593885b...
# 13354  [control, show-v2]  [[5edb13cb74d2112c99b45d17, 5e6cb10444bbc002a2...
# 13054  [control, show-v2]  [[6073f995c187127fe8f199ae, 622c41ed488cb48392...
# 13829  [control, show-v2]  [[6398c7f7b70aafff070fb2fd, 5f0581335982944586...
# 13329  [control, show-v2]  [[6247f396db0aa57413583f02, 60d144b5360189005e...
#
#        jaccard_top10
# 1984        0.116279
# 1021        0.099448
# 21          0.100559
# 984         0.096591
# 2027        0.183432
# ...              ...
# 13482       0.169591
# 13354       0.156977
# 13054       0.104972
# 13829       0.015306
# 13329       0.181818
#
# [120 rows x 5 columns]

# %%
display_recs = []
for i in df_group_sample.to_dict('records'):
    for ind in range(10):
        if ind > len(i['products'][0])-1:
            i[f'control_product_{ind}'] = None 
        else:
            pid = i['products'][0][ind]
            i[f'control_product_{ind}'] = pid # f"""=HYPERLINK("https://www.wish.com/product/{pid}", IMAGE("https://canary.contestimg.wish.com/api/webimage/{pid}-small.jpg"))"""
    for ind in range(10):
        if ind > len(i['products'][1])-1:
            i[f'treatment_product_{ind}'] = None 
        else:
            pid = i['products'][1][ind]
            i[f'treatment_product_{ind}'] = pid # f"""=HYPERLINK("https://www.wish.com/product/{pid}", IMAGE("https://canary.contestimg.wish.com/api/webimage/{pid}-small.jpg"))"""

    display_recs.append(i)

# %%
df_display = pd.DataFrame(display_recs)

# %%
df_display.to_csv('show-v1-v2-modelv3-retrieved_products_review.csv', index=False)

# %%
df_display
# Out:
#                         file                                query  \
# 0     show_v1_head_x1000.csv                     US_1_woman dress
# 1     show_v1_head_x1000.csv                         US_1_android
# 2     show_v1_head_x1000.csv                         US_0_android
# 3     show_v1_head_x1000.csv                     US_0_woman dress
# 4     show_v1_head_x1000.csv                           US_2_apple
# ..                       ...                                  ...
# 115  show_v2_torso_x1000.csv                 US_1_make up carrier
# 116  show_v2_torso_x1000.csv                            US_1_gems
# 117  show_v2_torso_x1000.csv                        US_1_atomiser
# 118  show_v2_torso_x1000.csv             US_1_vhs player for sale
# 119  show_v2_torso_x1000.csv  US_1_flight socks compression women
#
#                   split                                           products  \
# 0    [control, show-v1]  [[60fe1d2ed25d8ff937972f32, 5e96f2272acfce091b...
# 1    [control, show-v1]  [[63aaf4b98eead43909cb0527, 63b6d75f8b205e8fd7...
# 2    [control, show-v1]  [[63aaf4b98eead43909cb0527, 63b6d75f8b205e8fd7...
# 3    [control, show-v1]  [[5e96f2272acfce091bc80052, 60fe1d2ed25d8ff937...
# 4    [control, show-v1]  [[5dd71a00dd0c38cb85a85e49, 5e1659e41df5f12940...
# ..                  ...                                                ...
# 115  [control, show-v2]  [[60e81e5302d3fbb51330b8fe, 5fe9aee8d36593885b...
# 116  [control, show-v2]  [[5edb13cb74d2112c99b45d17, 5e6cb10444bbc002a2...
# 117  [control, show-v2]  [[6073f995c187127fe8f199ae, 622c41ed488cb48392...
# 118  [control, show-v2]  [[6398c7f7b70aafff070fb2fd, 5f0581335982944586...
# 119  [control, show-v2]  [[6247f396db0aa57413583f02, 60d144b5360189005e...
#
#      jaccard_top10         control_product_0         control_product_1  \
# 0         0.116279  60fe1d2ed25d8ff937972f32  5e96f2272acfce091bc80052
# 1         0.099448  63aaf4b98eead43909cb0527  63b6d75f8b205e8fd76f79c1
# 2         0.100559  63aaf4b98eead43909cb0527  63b6d75f8b205e8fd76f79c1
# 3         0.096591  5e96f2272acfce091bc80052  60fe1d2ed25d8ff937972f32
# 4         0.183432  5dd71a00dd0c38cb85a85e49  5e1659e41df5f1294079e7af
# ..             ...                       ...                       ...
# 115       0.169591  60e81e5302d3fbb51330b8fe  5fe9aee8d36593885b813ffa
# 116       0.156977  5edb13cb74d2112c99b45d17  5e6cb10444bbc002a224e279
# 117       0.104972  6073f995c187127fe8f199ae  622c41ed488cb483929536cd
# 118       0.015306  6398c7f7b70aafff070fb2fd  5f0581335982944586dd098c
# 119       0.181818  6247f396db0aa57413583f02  60d144b5360189005ead938d
#
#             control_product_2         control_product_3  \
# 0    5fadd9089b543b3e8a9ed09b  60c9ddbb02918b391426416e
# 1    62bace31908f27388f7afd84  6220bcedb99262a0a3021d74
# 2    62bace31908f27388f7afd84  6324cf41f5a94ed9d2abb507
# 3    5fadd9089b543b3e8a9ed09b  6362128480f2fe3e4e515fd0
# 4    60346a9650aa853b95dcf0a5  5bd3541ff299e32bf0372340
# 117  62c7f17883a447bb0f36856e  6073f995c187127fe8f199ae
# 118  618221d03781cec5ce0f8bbe  60920d0058fcceac3e3e3038
# 119  62e297e97b56000aef1c14c3  6335613a73abaa633bdd7c28
#
#           treatment_product_7       treatment_product_8  \
# 0    6109fb1148d2cf2f52ece89b  5fa913ed7953b807e1652bf3
# 1    62bace31908f27388f7afd84  61b241a3a4ee2ecaf2f63c77
# 2    61ad9d312f551851e917caee  624fa22df16e5d935944e2c2
# 3    5fa913ed7953b807e1652bf3  614564fba01ca57c6674ed03
# 4    62970e0440c360718c883ab6  5eaacb79de3c203ab0eb5188
# ..                        ...                       ...
# 115  5c78b24e9f99b44f1118c58c  5bb4a9f06b18016ef4e72b4d
# 116  5feeab79785f58b3b0688664  5edb13cb74d2112c99b45d17
# 117  62d13875bcdfc61e67e78188  634816fe18c44f3ec3f70bd0
# 118  63e4ea4570177fcf2fdfb09d  6127dd2693a43bf9f818359e
# 119  5e0edd1cc5805900815908cb  60e90de5f43c6da5c7c627a5
#
#           treatment_product_9
# 0    5edf03837104911ce1ca3a8b
# 1    63aaf4b98eead43909cb0527
# 2    61b241a3a4ee2ecaf2f63c77
# 3    591a9fb849043a3602182949
# 4    6360bf3a00f06f2c20396bfd
# ..                        ...
# 115  5a17e773061be93a980b352f
# 116  5cb7202979525e4e61145528
# 117  626fd8cf753744561cbc29c9
# 118  606653886fc9054ad7cd1b63
# 119  5a1297f8471c1461c87b9489
#
# [120 rows x 25 columns]

# %%
df_res = pd.read_csv('show-v1-v2-modelv3-retrieved_products_review_results.csv')

# %%
for i in ['winner_relevance', 'winner_gmv', 'comment']:
    df_res[i] = df_res[i].apply(lambda x: str(x).lower().strip())

# %%
df_res['winner_relevance'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='winner_relevance'>

# %%
df_res['winner_gmv'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='winner_gmv'>

# %%
df_res['comment'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='comment'>

# %%
from collections import Counter

# %%
df_res.groupby('file').agg(
    winner_relevance_control = ('winner_relevance', lambda x: len([i for i in x if i == 'control']) / len(x)),
    winner_relevance_treatment = ('winner_relevance', lambda x: len([i for i in x if i == 'treatment']) / len(x)),
    winner_relevance_notsure = ('winner_relevance', lambda x: len([i for i in x if i != 'control' and i != 'treatment']) / len(x)),

    winner_gmv_control = ('winner_gmv', lambda x: len([i for i in x if i == 'control']) / len(x)),
    winner_gmv_treatment = ('winner_gmv', lambda x: len([i for i in x if i == 'treatment']) / len(x)),
    winner_gmv_notsure = ('winner_gmv', lambda x: len([i for i in x if i != 'control' and i != 'treatment']) / len(x)),
).reset_index()
# Out:
#                       file  winner_relevance_control  \
# 0   show_v1_head_x1000.csv                      0.05
# 1   show_v1_tail_x1000.csv                      0.15
# 2  show_v1_torso_x1000.csv                      0.05
# 3   show_v2_head_x1000.csv                      0.05
# 4   show_v2_tail_x1000.csv                      0.05
# 5  show_v2_torso_x1000.csv                      0.00
#
#    winner_relevance_treatment  winner_relevance_notsure  winner_gmv_control  \
# 0                        0.15                      0.80                0.05
# 1                        0.15                      0.70                0.15
# 2                        0.30                      0.65                0.05
# 3                        0.20                      0.75                0.05
# 4                        0.25                      0.70                0.05
# 5                        0.20                      0.80                0.00
#
#    winner_gmv_treatment  winner_gmv_notsure
# 0                  0.15                0.80
# 1                  0.15                0.70
# 2                  0.30                0.65
# 3                  0.20                0.75
# 4                  0.25                0.70
# 5                  0.20                0.80
